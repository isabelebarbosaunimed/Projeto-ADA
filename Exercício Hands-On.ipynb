# %% [markdown]
# Hands-On
# Você foi designado para realizar a limpeza e preparação de dados de dois conjuntos de dados (base1.csv e base2.csv) distintos que representam informações relacionadas a risco de crédito.
#
# Seu objetivo é ler os dois conjuntos de dados usando a biblioteca Pandas, realizar a concatenação dos dados, lidar com valores duplicados e faltantes, além de verificar a presença de outliers nos dados combinados.
#
# Passos a serem seguidos:
# Leitura dos Arquivos: Utilize a biblioteca Pandas para ler os dois arquivos de dados: 'base1.csv' e 'base2.csv', que estão no diretório datasets, no repositório do módulo.
# Concatenação dos Dados: Concatene os dois conjuntos de dados em um único DataFrame, verificando se os dados possuem a mesma estrutura para uma concatenação adequada.
# Tratamento de Dados Duplicados: Verifique se há linhas duplicadas no DataFrame combinado e remova-as, mantendo a primeira ocorrência.
# Tratamento de Valores Faltantes: Identifique e lide com os valores faltantes no DataFrame combinado. Preencha os valores ausentes com estratégias apropriadas (média, mediana, valor específico etc.) dependendo do contexto dos dados.
# Verificação de Outliers: Utilize métodos estatísticos ou gráficos (como boxplots) para identificar a presença de outliers nos dados. Considere se eles são significativos para a análise ou se precisam ser tratados de alguma forma.

# %%
#Leitura dos Arquivos: Utilize a biblioteca Pandas para ler os dois arquivos de dados: 'base1.csv' e 'base2.csv', que estão no diretório datasets, no repositório do módulo.

import pandas as pd

base1 = pd.read_csv('/Workspace/Repos/isabele@unimedcampinas.com.br/ADA_classes/DS-PY-Data-Science/DS-PY-004 TÉCNICAS DE PROGRAMAÇÃO I (PY)/Material do Aluno/datasets/base1.csv').drop(columns=['Unnamed: 0','Unnamed: 0.1'])
base1
# Out:
#      Age     Sex  Job  ... Duration              Purpose  Risk
# 0     26    male    2  ...       12                  car  good
# 1     61    male    2  ...       18            education  good
# 2     50    male    2  ...        6                  car  good
# 3     42    male    2  ...       36                  car  good
# 4     26  female    2  ...       24  furniture/equipment  good
# ..   ...     ...  ...  ...      ...                  ...   ...
# 665   36    male    2  ...       11                  car  good
# 666   22  female    2  ...       12  furniture/equipment  good
# 667   27    male    2  ...       36              repairs  good
# 668   29    male    1  ...       12  furniture/equipment  good
# 669   49    male    2  ...       24                  car  good
#
# [670 rows x 10 columns]

# %%
base2 = pd.read_csv('/Workspace/Repos/isabele@unimedcampinas.com.br/ADA_classes/DS-PY-Data-Science/DS-PY-004 TÉCNICAS DE PROGRAMAÇÃO I (PY)/Material do Aluno/datasets/base2.csv').drop(columns=['Unnamed: 0','Unnamed: 0.1'])
base2
# Out:
#      Age     Sex  Job  ... Duration              Purpose  Risk
# 0     41    male    1  ...       21             business   bad
# 1     26    male    2  ...       36                  car   bad
# 2     27    male    2  ...       24  furniture/equipment  good
# 3     29    male    1  ...       24  furniture/equipment  good
# 4     35    male    2  ...       24                  car  good
# ..   ...     ...  ...  ...      ...                  ...   ...
# 325   32    male    2  ...       48             radio/TV  good
# 326   38    male    2  ...       48             business  good
# 327   20  female    2  ...       12                  car  good
# 328   30    male    3  ...       24             radio/TV   bad
# 329   19  female    2  ...        9  furniture/equipment   bad
#
# [330 rows x 10 columns]

# %%
#Concatenação dos Dados: Concatene os dois conjuntos de dados em um único DataFrame, verificando se os dados possuem a mesma estrutura para uma concatenação adequada.

Dados_unificados = pd.concat([base1, base2])
Dados_unificados
# Out:
#      Age     Sex  Job  ... Duration              Purpose  Risk
# 0     26    male    2  ...       12                  car  good
# 1     61    male    2  ...       18            education  good
# 2     50    male    2  ...        6                  car  good
# 3     42    male    2  ...       36                  car  good
# 4     26  female    2  ...       24  furniture/equipment  good
# ..   ...     ...  ...  ...      ...                  ...   ...
# 325   32    male    2  ...       48             radio/TV  good
# 326   38    male    2  ...       48             business  good
# 327   20  female    2  ...       12                  car  good
# 328   30    male    3  ...       24             radio/TV   bad
# 329   19  female    2  ...        9  furniture/equipment   bad
#
# [1000 rows x 10 columns]

# %%
#Tratamento de Dados Duplicados: Verifique se há linhas duplicadas no DataFrame combinado e remova-as, mantendo a primeira ocorrência. 
#Não existem dados duplicados. 

Dados_unificados.loc[Dados_unificados.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Job, Housing, Saving accounts, Checking account, Credit amount, Duration, Purpose, Risk]
# Index: []

# %%
#Tratamento de Valores Faltantes: Identifique e lide com os valores faltantes no DataFrame combinado. #Preencha os valores ausentes com estratégias apropriadas (média, mediana, valor específico etc.) dependendo do contexto dos dados.

Dados_unificados.isna().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
Dados_unificados.fillna('Uninformed')
# Out:
#      Age     Sex  Job  ... Duration              Purpose  Risk
# 0     26    male    2  ...       12                  car  good
# 1     61    male    2  ...       18            education  good
# 2     50    male    2  ...        6                  car  good
# 3     42    male    2  ...       36                  car  good
# 4     26  female    2  ...       24  furniture/equipment  good
# ..   ...     ...  ...  ...      ...                  ...   ...
# 325   32    male    2  ...       48             radio/TV  good
# 326   38    male    2  ...       48             business  good
# 327   20  female    2  ...       12                  car  good
# 328   30    male    3  ...       24             radio/TV   bad
# 329   19  female    2  ...        9  furniture/equipment   bad
#
# [1000 rows x 10 columns]

# %%
#Verificação de Outliers: Utilize métodos estatísticos ou gráficos (como boxplots) para identificar a presença de outliers nos dados. Considere se eles são significativos para a análise ou se precisam ser tratados de alguma forma.

import matplotlib.pyplot as plt
Dados_unificados.boxplot()
plt.title('Análise de Crédito')
plt.xlabel('Risk')
plt.ylabel('Credit amount')
plt.show()
